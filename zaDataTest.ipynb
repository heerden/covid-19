# %%
# Notebook Automation
# https://github.com/yaananth/run-notebook
# !pip install nteract-scrapbook

import uuid
output = str(uuid.uuid4())

import scrapbook as sb
sb.glue("output", output)
# Out:
# Requirement already satisfied: nteract-scrapbook in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (0.4.1)
# Requirement already satisfied: pandas in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nteract-scrapbook) (1.0.1)
# Requirement already satisfied: ipython in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nteract-scrapbook) (7.12.0)
# Requirement already satisfied: papermill in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nteract-scrapbook) (2.1.1)
# Requirement already satisfied: jsonschema in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nteract-scrapbook) (3.2.0)
# Requirement already satisfied: pyarrow in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nteract-scrapbook) (0.17.0)
# Requirement already satisfied: pytz>=2017.2 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from pandas->nteract-scrapbook) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from pandas->nteract-scrapbook) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from pandas->nteract-scrapbook) (1.18.1)
# Requirement already satisfied: decorator in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (4.4.1)
# Requirement already satisfied: backcall in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (0.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (4.8.0)
# Requirement already satisfied: appnope; sys_platform == "darwin" in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (0.14.1)
# Requirement already satisfied: pygments in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (2.5.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (3.0.3)
# Requirement already satisfied: pickleshare in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (4.3.3)
# Requirement already satisfied: setuptools>=18.5 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ipython->nteract-scrapbook) (46.0.0.post20200309)
# Requirement already satisfied: black in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (19.10b0)
# Requirement already satisfied: click in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (7.0)
# Requirement already satisfied: tqdm>=4.32.2 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (4.42.1)
# Requirement already satisfied: pyyaml in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (5.3)
# Requirement already satisfied: requests in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (2.22.0)
# Requirement already satisfied: tenacity in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (6.2.0)
# Requirement already satisfied: ansiwrap in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (0.8.4)
# Requirement already satisfied: nbclient>=0.2.0 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (0.2.0)
# Requirement already satisfied: nbformat in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (5.0.4)
# Requirement already satisfied: jupyter-client in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (5.3.4)
# Requirement already satisfied: entrypoints in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from papermill->nteract-scrapbook) (0.3)
# Requirement already satisfied: six>=1.11.0 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->nteract-scrapbook) (1.14.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->nteract-scrapbook) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->nteract-scrapbook) (1.5.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from jsonschema->nteract-scrapbook) (0.15.7)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython->nteract-scrapbook) (0.6.0)
# Requirement already satisfied: parso>=0.5.0 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from jedi>=0.10->ipython->nteract-scrapbook) (0.5.2)
# Requirement already satisfied: wcwidth in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->nteract-scrapbook) (0.1.8)
# Requirement already satisfied: ipython-genutils in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from traitlets>=4.2->ipython->nteract-scrapbook) (0.2.0)
# Requirement already satisfied: toml>=0.9.4 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from black->papermill->nteract-scrapbook) (0.10.0)
# Requirement already satisfied: regex in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from black->papermill->nteract-scrapbook) (2020.4.4)
# Requirement already satisfied: typed-ast>=1.4.0 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from black->papermill->nteract-scrapbook) (1.4.1)
# Requirement already satisfied: pathspec<1,>=0.6 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from black->papermill->nteract-scrapbook) (0.8.0)
# Requirement already satisfied: appdirs in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from black->papermill->nteract-scrapbook) (1.4.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from requests->papermill->nteract-scrapbook) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from requests->papermill->nteract-scrapbook) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from requests->papermill->nteract-scrapbook) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from requests->papermill->nteract-scrapbook) (3.0.4)
# Requirement already satisfied: textwrap3>=0.9.2 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from ansiwrap->papermill->nteract-scrapbook) (0.9.2)
# Requirement already satisfied: nest-asyncio in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nbclient>=0.2.0->papermill->nteract-scrapbook) (1.3.2)
# Requirement already satisfied: async-generator in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nbclient>=0.2.0->papermill->nteract-scrapbook) (1.10)
# Requirement already satisfied: jupyter-core in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from nbformat->papermill->nteract-scrapbook) (4.6.1)
# Requirement already satisfied: pyzmq>=13 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->papermill->nteract-scrapbook) (18.1.1)
# Requirement already satisfied: tornado>=4.1 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from jupyter-client->papermill->nteract-scrapbook) (6.0.3)
# Requirement already satisfied: zipp>=0.5 in /Users/schalk/opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema->nteract-scrapbook) (2.2.0)

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/dsfsi/covid19za/master/data/covid19za_provincial_cumulative_timeline_confirmed.csv'
states_all = pd.read_csv(url,
                     parse_dates=['date'], dayfirst=True,
                     squeeze=True).sort_index()
states_all = states_all.rename(columns={'total':'Total'})

# filter data if required
#state_filter = states_all[:-1];
states = states_all
states.tail()
# Out:
#          date  YYYYMMDD     EC     FS      GP     KZN    LP    MP    NC    NW  \
# 51 2020-04-27  20200427  588.0  111.0  1353.0   902.0  31.0  26.0  17.0  31.0
# 52 2020-04-28  20200428  616.0  113.0  1377.0   919.0  31.0  26.0  17.0  29.0
# 53 2020-04-29  20200429  630.0  113.0  1408.0   956.0  31.0  31.0  17.0  29.0
# 54 2020-04-30  20200430  647.0  116.0  1446.0   980.0  32.0  36.0  17.0  31.0
# 55 2020-05-01  20200501  691.0  118.0  1507.0  1006.0  34.0  35.0  18.0  18.0
#
#         WC  UNKNOWN  Total RSA  \
# 51  1737.0      0.0       4793
# 52  1870.0      0.0       4996
# 53  2135.0      0.0       5350
# 54  2342.0      0.0       5647
# 55  2507.0      0.0       5951
#
#                                                source
# 51  https://twitter.com/drzwelimkhize/status/12548...
# 52  https://twitter.com/COVID_19_ZA/status/1255200...
# 53  https://sacoronavirus.co.za/2020/04/29/update-...
# 54  https://sacoronavirus.co.za/2020/04/30/update-...
# 55  https://sacoronavirus.co.za/2020/05/01/update-...

# %%
# Uncomment the following line if you'd like to export the data
states.to_csv('data/testdata.csv')
